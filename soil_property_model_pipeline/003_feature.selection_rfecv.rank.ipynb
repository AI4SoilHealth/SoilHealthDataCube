# %%
import numpy as np
import matplotlib.pyplot as plt
import multiprocess as mp
import glob
import time
from tqdm import tqdm
import os
import sys
import pandas as pd
from eumap.misc import find_files, ttprint
from eumap.raster import read_rasters, save_rasters
from eumap.mapper import SpaceOverlay
import geopandas as gpd
from pathlib import Path
import rasterio
import pyproj
from shapely.geometry import Point
from eumap.mapper import LandMapper
from scipy.special import expit, logit

import warnings

import matplotlib
import matplotlib.pyplot as plt

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, cross_val_score, HalvingGridSearchCV, KFold, GroupKFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor

import joblib
import pickle

folder = '/mnt/primus/xuemeng_tmp_harbour/soc'
df = pd.read_csv(f'{folder}/data/006.0_cal.pnts_oc.csv',low_memory=False)
# df = pd.read_csv(f'{folder}/data/006.1_cal.pnts_oc.org.csv',low_memory=False)
# df = pd.read_csv(f'{folder}/data/006.2_cal.pnts_oc.mnr.csv',low_memory=False)
# df = pd.concat([df] * 10, ignore_index=True)

# target
tgt = 'oc_log1p'

# covariates
meta_info = ['id','lat','lon','time','ref','nuts0','geometry','tile_id']
meta_prop = ['oc','ph_h2o','ph_cacl2','bulk_density','clay','silt','sand','caco3','N','K','P','CEC','EC']
meta_qa = [i+'_qa' for i in meta_prop]
meta = meta_info + meta_prop + meta_qa + [tgt]
covs = [i for i in df.columns if i not in meta]

dff = df.dropna(subset=covs,how='any')

# %% [markdown]
# ### Feature selection with RFECV

# %%
# a function to determine optimal number of features
from sklearn.model_selection import GroupKFold, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFECV, RFE
from scipy.signal import argrelmin, argrelmax
import joblib
import random
import multiprocessing

def run_rfecv(data, covs, target_column, scoring, min_feature = 10, errorbar=True, spatial_cv_column = None, n_rep = 5, n_cv = 3, ntrees = 100, local_max_pos = 1):
    rfecv_step = int(len(covs) * 0.05)
    random_numbers = [random.randint(0, 99) for _ in range(n_rep)]

    ncpu = multiprocessing.cpu_count()
    if ntrees < ncpu:
        ncpu = ntrees

    ttprint(f"Finding n_features_to_select using RFECV (repetitions={n_rep} step={rfecv_step}), data size {len(data)}")
    
    grid_scores = []
    rfecv_n_features_arr = np.arange(len(covs), min_feature-1, - rfecv_step)[::-1]
    for i in range(0,n_rep):
        # randomly select subsample of the data to do the rfecv
        ttprint(f'loop {i}')
        
        # cross validation with spatial blocking
        cv, groups = KFold(n_cv), None
        if spatial_cv_column is not None:
            cv, groups = GroupKFold(n_cv), train[spatial_cv_column]
        
        # start the RFECV process
        rfecv = RFECV(estimator=RandomForestRegressor(n_estimators=ntrees, n_jobs=ncpu, random_state=random_numbers[i]), cv=cv, step=rfecv_step, 
            min_features_to_select=min_feature, n_jobs=n_cv, scoring=scoring, verbose=0)
        rfecv.fit(data[covs], data[target_column], groups=groups)
        
        # get the score and visualize
        grid_scores += [rfecv.cv_results_['mean_test_score']]
    
        plt.figure()
        plt.xlabel("Number of features selected")
        plt.ylabel(f'Cross validation {scoring}')
        plt.title(f'iter: {i}, select {rfecv.n_features_} features')
#         print(rfecv.cv_results_["mean_test_score"])
        if errorbar:
            plt.errorbar(
                rfecv_n_features_arr,
                rfecv.cv_results_["mean_test_score"][0:-1],
                yerr=rfecv.cv_results_["std_test_score"][0:-1],
            )
        else:
            plt.plot(rfecv_n_features_arr, rfecv.cv_results_["mean_test_score"][0:-1])
        plt.show()

    rfecv_mean_score = np.mean(np.stack(grid_scores, axis=0), axis=0)
    grid_scores_std = np.std(np.stack(grid_scores, axis=0), axis=0)
    
#     local_min_arr = argrelmin(rfecv_mean_score, order=1)[0]
#     local_min = local_min_arr[0]
#     if len(local_min_arr) > 1:
#         local_min = local_min_arr[local_min_pos]
    local_max_arr = argrelmax(rfecv_mean_score, order=1)[0]
    local_max = local_max_arr[0]
    if len(local_max_arr) > 1:
        local_max = local_max_arr[local_max_pos]
    n_features_to_select = rfecv_n_features_arr[local_max]

    ttprint(f"Finding best features using RFE (n_features_to_select = {n_features_to_select})")
    
    return grid_scores, rfecv_mean_score, grid_scores_std, n_features_to_select 

# rfecv selection
grid_scores, rfecv_mean_score, grid_scores_std, feature_num = run_rfecv(train, covs, tgt, scoring = 'neg_mean_squared_error', errorbar=False,spatial_cv_column='tile_id')
# Out:
# [16:32:52] Finding n_features_to_select using RFECV (repetitions=5 step=24), data size 51560
# [16:32:52] loop 0
# [16:54:01] loop 1
# [17:15:22] loop 2
# [17:36:49] loop 3
# [17:56:50] loop 4
# [18:17:52] Finding best features using RFE (n_features_to_select = 243)

# %%
min_feature = 10
rfecv_step = int(len(covs) * 0.05)
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel(f'Cross validation r2')
plt.title(f'average iter, optimal feature number: {feature_num}') 

number_arr = np.arange(len(covs), min_feature-1, -rfecv_step)[::-1]

plt.errorbar(number_arr, rfecv_mean_score[0:-1], yerr=grid_scores_std[0:-1])

specific_index = np.where(number_arr == feature_num)[0][0]

plt.errorbar(
    feature_num,
    rfecv_mean_score[specific_index],
    yerr=grid_scores_std[specific_index],
    fmt='o', color='red', label=f'Optimal feature number')
    
plt.show()

# %% [markdown]
# #### Determine the optimal set of covariate number with RFE

# %%
feature_num = 197
rfe = RFE(estimator=RandomForestRegressor(n_estimators=100, n_jobs=70, random_state=0),
          step=int(len(covs) * 0.02),
          n_features_to_select=feature_num,
          verbose=0)

# train, _ = train_test_split(dff, test_size=0.5, random_state=42, stratify=dff['tile_id'])
# train = dff.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(min(len(x), 10)))

rfe.fit(train[covs], train[tgt].values)
selected_features = np.array(covs)[rfe.support_]

# get the feature importance
rf = RandomForestRegressor(n_estimators=50, n_jobs=80, random_state=0)
rf.fit(train[selected_features], train[tgt].values)
# train_r2 = rf.score(train_set[selected_features], train_set[tgt].values)
# test_r2 = rf.score(test_set[selected_features], test_set[tgt].values)
# print("Training R^2 score:", train_r2)
# print("Testing R^2 score:", test_r2)

importances = rf.feature_importances_
feature_importances = dict(zip(selected_features, importances))
feature_importances = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)
feature_importances = dict(feature_importances)

# %%
with open(f'{folder}/SOC-EU/features/001_selected.covar_rfecv.txt', 'w') as file:
    for item in selected_features:
        file.write(f"{item}\n")
     
feature_importances
# Out:
# {'pft.grass.man_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616': 0.17805075799516792,
#  'ndti_glad.landast.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.09484828829588626,
#  'bioclim.var_chelsa.gdd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0818517678749068,
#  'hzn_btm': 0.05000556341842082,
#  'red_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.02365275945379934,
#  'lithology_EGDI_peat': 0.017816334569167355,
#  'bioclim.var_chelsa.gsp_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.014092423380134368,
#  'bioclim.var_chelsa.bio4_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.009108314907392761,
#  'bioclim.var_chelsa.gdgfgd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.009083815601838088,
#  'accum.ndti_glad.landsat.seasconv.m.yearly_min_30m_s_{year}0101_{year}_eu_epsg.3035_v20240513': 0.006477932612510672,
#  'bioclim.var_chelsa.bio10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0063185078125369745,
#  'hzn_top': 0.006212229262544604,
#  'red_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.00614004466651729,
#  'slope.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.005812241714452346,
#  'twi.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.005121066243276506,
#  'neg.openess.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.004670880540724531,
#  'bioclim.var_chelsa.npp_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0045517964842191234,
#  'bioclim.var_chelsa.bio14_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.004496043621921204,
#  'bioclim.var_chelsa.bio13_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.004468550909513666,
#  'bioclim.var_chelsa.bio18_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.004453573521307218,
#  'ndti.min_glad.landsat.ard2.seasconv.bimonthly.min_m_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218': 0.00427427412545622,
#  'bioclim.var_chelsa.bio7_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.004240239562390854,
#  'red_glad.landsat.seasonv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211': 0.004068750409605242,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.01.01..{year}.01.31_v2.1': 0.00402221256608615,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.11.01..{year}.11.30_v2.1': 0.003978857417771752,
#  'dtm.bareearth_ensemble_p10_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.003958534930345365,
#  'thermal_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211': 0.003841262980332506,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.08.01..{year}.08.31_v2.1': 0.0038219266574934354,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127': 0.003548577625298889,
#  'bioclim.var_chelsa.bio3_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.003546511295042029,
#  'twi.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003542231797487849,
#  'green_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.0035321596553110385,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.10.01..{year}.10.31_v2.1': 0.0035110999657417454,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127': 0.003495317661621136,
#  'bioclim.var_chelsa.bio15_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0034403660299454357,
#  'evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127': 0.0033848901941077292,
#  'max.curv.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0033786886486728246,
#  'flow.accum.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0033776597685648267,
#  'max.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003337345151610837,
#  'spec.catch.area.factor.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003314605612471112,
#  'twi.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0033050218625166007,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0601_{year}0630_go_epsg.4326_v20230619': 0.003238949475256894,
#  'bioclim.var_chelsa.gst_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0031993160349532753,
#  'slope.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003197845389747883,
#  'accum.ndvi_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20240513': 0.003179449581042941,
#  'bioclim.var_chelsa.bio16_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0031687826181484384,
#  'slope.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003128002311725436,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}1001_{year}1031_go_epsg.4326_v20230619': 0.0030905244975171714,
#  'bioclim.var_chelsa.bio12_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0030851393823521996,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0901_{year}0930_go_epsg.4326_v20230619': 0.0030550798112849486,
#  'clm_accum.precipitation_chelsa.annual.3years.dif_m_1km_s0..0cm_{year}_v2.1': 0.0030502131427599753,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}1001_{year}1031_go_epsg.4326_v20230619': 0.003044880094226718,
#  'spec.catch.area.factor.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.003030347021189008,
#  'max.curv.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002968917787291056,
#  'twi.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0029594123127747,
#  'spec.catch.area.factor.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0029584132150064267,
#  'easterness.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.002947613261122887,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0801_{year}0831_go_epsg.4326_v20230619': 0.0029408698799724404,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127': 0.00293031259566287,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0501_{year}0531_go_epsg.4326_v20230619': 0.0029115058428435155,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0501_{year}0531_go_epsg.4326_v20230619': 0.0029085129942846115,
#  'northness.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.002898912910212588,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.07.01..{year}.07.31_v2.1': 0.002898387194705034,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2': 0.002878071150954149,
#  'dtm.bareearth_ensemble_p10_960m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.0028716910187136235,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127': 0.0028599127598475916,
#  'min.curv.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0028585120017850336,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.02.01..{year}.02.28_v2.1': 0.002847722799303299,
#  'evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127': 0.0028272009758266935,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2': 0.0028100886412702176,
#  'slope.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002805692700709085,
#  'min.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.002805435946340412,
#  'bioclim.var_chelsa.bio19_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0027989281251879906,
#  'bioclim.var_chelsa.bio6_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.002781160751332569,
#  'slope.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0027747488789293994,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.09.01..{year}.09.30_v2.1': 0.0027573449544331485,
#  'twi.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002744332806362713,
#  'ndwi.gao_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218': 0.0027419620895374293,
#  'min.curv.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0027329738693300932,
#  'spec.catch.area.factor.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0027300127828232988,
#  'green_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.0027201774138339726,
#  'clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2': 0.0026949959365438116,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}1101_{year}1130_go_epsg.4326_v20230619': 0.002689204538200991,
#  'bioclim.var_chelsa.bio8_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0026700350407143658,
#  'clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2': 0.002648160160506752,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.03.01..{year}.03.31_v2.1': 0.0026437892691798465,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.04.01..{year}.04.30_v2.1': 0.0026433242800890733,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.06.01..{year}.06.30_v2.1': 0.00263460681333687,
#  'nir_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211': 0.002632782273438023,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2': 0.0026315512943502896,
#  'ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231218': 0.0026144546208299547,
#  'clm_accum.precipitation_chelsa.annual_m_1km_s0..0cm_{year}_v2.1': 0.002589806120806698,
#  'max.curv.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002583832667162282,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.05.01..{year}.05.31_v2.1': 0.0025798441175319477,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}1201_{year}1231_go_epsg.4326_v20230619': 0.0025682089593385363,
#  'clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2': 0.0025648364878264962,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.0025552033980171906,
#  'slope.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0025477052771063374,
#  'swir1_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211': 0.0025462419302127483,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0101_{year}0131_go_epsg.4326_v20230619': 0.002539499454682647,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2': 0.0025352512724837817,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}_v1.2': 0.0025298233169117118,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2': 0.0025265749429807844,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0901_{year}0930_go_epsg.4326_v20230619': 0.002521046709509603,
#  'bioclim.var_chelsa.bio11_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.002516673482931841,
#  'nir_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211': 0.002514506112325294,
#  'ndvi_glad.landast.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.002513870963046085,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0101_{year}0131_go_epsg.4326_v20230619': 0.0024957303570628457,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2': 0.0024936408278095736,
#  'min.curv.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002486397609666525,
#  'accum.ndvi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513': 0.002483937761556847,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2': 0.0024718023010652087,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2': 0.0024663468549763127,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0201_{year}0228_go_epsg.4326_v20230619': 0.0024662660426072996,
#  'green_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211': 0.002460801441628735,
#  'clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2': 0.0024536939824248345,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127': 0.0024439332815161083,
#  'bioclim.var_chelsa.bio2_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.002437845487498348,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2': 0.0024346022440231638,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}1201_{year}1231_go_epsg.4326_v20230619': 0.002429555496935376,
#  'ndti_glad.landast.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.0024289978060002657,
#  'clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2': 0.00242717437170892,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0601_{year}0630_go_epsg.4326_v20230619': 0.0024058588704653524,
#  'ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127': 0.0024054425699152203,
#  'ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231218': 0.0023944189765675067,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2': 0.0023907376646061292,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0701_{year}0731_go_epsg.4326_v20230619': 0.0023834450511374464,
#  'wv_mcd19a2v061.seasconv.m.yearly_p50_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619': 0.002381863666386461,
#  'ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231218': 0.0023771362303043942,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2': 0.0023711342922505233,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2': 0.002367224419355219,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0201_{year}0228_go_epsg.4326_v20230619': 0.0023638904972957922,
#  'bioclim.var_chelsa.bio9_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.0023601672833720375,
#  'dtm.bareearth_ensemble_p10_240m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.0023529153047940382,
#  'clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.12.01..{year}.12.31_v2.1': 0.0023450135784956537,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2': 0.0023379866800920836,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0401_{year}0430_go_epsg.4326_v20230619': 0.0023325005250460404,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}1101_{year}1130_go_epsg.4326_v20230619': 0.0023223392805859413,
#  'nir_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211': 0.0023115868136469463,
#  'min.curv.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0023111497458257056,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.0023081625212002964,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2': 0.0022989624160141635,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2': 0.002297136422079172,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0301_{year}0331_go_epsg.4326_v20230619': 0.0022942101536002164,
#  'accum.ndwi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513': 0.00229121111883345,
#  'clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2': 0.0022911745806578326,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2': 0.002290085680435792,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2': 0.002261017166819936,
#  'neg.openess.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002259567320630358,
#  'clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.0022518453035018007,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2': 0.002243620962438702,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2': 0.002240436471831092,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2': 0.0022389564033272204,
#  'evi_glad.landsat.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127': 0.002209992195072087,
#  'swir1_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211': 0.002206275469967071,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2': 0.0022060524037683005,
#  'max.curv.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.002206001846516611,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2': 0.0022008460206729137,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}_v1.2': 0.0021995368608359483,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2': 0.0021978937537872325,
#  'ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127': 0.0021903411855615494,
#  'clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2': 0.002183079113071092,
#  'fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127': 0.0021711353148264824,
#  'wv_mcd19a2v061.seasconv.m.yearly_sd_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619': 0.0021621915428864215,
#  'ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127': 0.0021585531815661876,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0301_{year}0331_go_epsg.4326_v20230619': 0.0021442749749767324,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127': 0.002143717340930896,
#  'wv_mcd19a2v061.seasconv_sd_1km_s_{year}0401_{year}0430_go_epsg.4326_v20230619': 0.002138406827595395,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0801_{year}0831_go_epsg.4326_v20230619': 0.0021370716585480086,
#  'ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231218': 0.002125947339646323,
#  'ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127': 0.002123333433196694,
#  'clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2': 0.0021222305052004554,
#  'bioclim.var_chelsa.bio5_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.002121221915673057,
#  'clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.002120973783089936,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0701_{year}0731_go_epsg.4326_v20230619': 0.002118125485411803,
#  'max.curv.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0021133781902225495,
#  'evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127': 0.0021121066392718077,
#  'swir1_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211': 0.002109234970767474,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2': 0.0021078917634385994,
#  'swir1_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211': 0.0021029407718441144,
#  'nir_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.002090794288705772,
#  'clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}_v1.2': 0.0020872452330873113,
#  'ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231218': 0.002085484352278076,
#  'swir1_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211': 0.0020851241593407353,
#  'ls.factor.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.0020700000821028334,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2': 0.0020690811580814567,
#  'clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2': 0.0020659827273541874,
#  'nir_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211': 0.0020653999247904763,
#  'clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2': 0.0020266623951573823,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2': 0.002020602012386395,
#  'clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2': 0.002008268593635097,
#  'clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.0019822227605238,
#  'clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2': 0.001980249859920748,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2': 0.0019675432427248398,
#  'clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2': 0.0019472960334358674,
#  'clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2': 0.0019291035436605616,
#  'clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2': 0.001897648041698695}

# %% [markdown]
# ### Rank frequency

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer
from tool_kit import calc_ccc

ccc_scorer = make_scorer(calc_ccc, greater_is_better=True)

# scores = cross_val_score(rf, train[covs], train[tgt], cv=5, scoring=ccc_scorer)

# # Printing the scores
# print("CCC scores for each fold:", scores)
# print("Average CCC score:", np.mean(scores))

# %%
from sklearn.ensemble import RandomForestRegressor
def run_rankcv(data, covs, tgt, spatial_cv_column, weights_feature=None, n_bootstrap=20, ntrees = 100):

    groups = data[spatial_cv_column].unique()
    runs = []
    
    # loop on different bootstrap
    for k in range(n_bootstrap):
        
        np.random.seed(k)
        selected_groups = np.random.choice(groups, int(len(groups) * 0.7), False)  # each time cover 70% of the tiles
        samples_train = data[data[spatial_cv_column].isin(selected_groups)]
        train = samples_train.groupby(spatial_cv_column, group_keys=False).apply(lambda x: x.sample(min(len(x), 20)))  # make sure to select enough data for training
        
        ttprint(f'{k} iteration, training size: {len(train)}')
        # Get weights if applicable
        if weights_feature:
            weights = train[weights_feature].to_numpy()
            rf = RandomForestRegressor(random_state=41, n_jobs=80, n_estimators=ntrees)
            rf.fit(train[covs], train[tgt], sample_weight=weights)
        else:
            rf = RandomForestRegressor(random_state=41, n_jobs=80, n_estimators=ntrees)
            rf.fit(train[covs], train[tgt])

        importances = pd.Series(rf.feature_importances_, index=covs).sort_values(ascending=True)
        importances = importances[importances>=importances.mean()]
        runs.append((importances.index, np.array(importances.to_list())))
        
    result = pd.DataFrame(
        dict(feature=[feature for run in runs for feature in run[0]], 
             importance=[importance for run in runs for importance in run[1]])
    )

    return result


result = run_rankcv(dff, covs, tgt, spatial_cv_column='tile_id')
feature_list = result.groupby(['feature']).count().rename(columns=dict(importance='freq')).reset_index()

features_freq = feature_list.groupby('freq').count().reset_index().sort_values(by='freq', ascending=False)
features_freq['accum'] = features_freq['feature'].cumsum()
features_freq

# print(feature_list.sort_values(by='freq', ascending=False).to_string())
# Out:
# [12:58:17] 0 iteration, training size: 8549
# [12:58:29] 1 iteration, training size: 8481
# [12:58:41] 2 iteration, training size: 8519
# [12:58:55] 3 iteration, training size: 8549
# [12:59:07] 4 iteration, training size: 8537
# [12:59:19] 5 iteration, training size: 8514
# [12:59:31] 6 iteration, training size: 8514
# [12:59:44] 7 iteration, training size: 8628
# [12:59:55] 8 iteration, training size: 8499
# [13:00:07] 9 iteration, training size: 8479
# [13:00:20] 10 iteration, training size: 8689
# [13:00:32] 11 iteration, training size: 8597
# [13:00:44] 12 iteration, training size: 8518
# [13:00:56] 13 iteration, training size: 8652
# [13:01:08] 14 iteration, training size: 8661
# [13:01:20] 15 iteration, training size: 8601
# [13:01:32] 16 iteration, training size: 8573
# [13:01:45] 17 iteration, training size: 8653
# [13:01:57] 18 iteration, training size: 8605
# [13:02:09] 19 iteration, training size: 8640
#     freq  feature  accum
# 19    20       17     17
# 18    19        6     23
# 17    18        7     30
# 16    17        1     31
# 15    16        4     35
# 14    15        2     37
# 13    14        7     44
# 12    13        3     47
# 11    12        2     49
# 10    11        5     54
# 9     10        4     58
# 8      9        6     64
# 7      8        9     73
# 6      7        7     80
# 5      6        5     85
# 4      5        6     91
# 3      4       13    104
# 2      3       16    120
# 1      2       10    130
# 0      1       34    164

# %%
features_freq.loc[features_freq['feature']==features_freq['feature'].min(),'freq'].values
# Out:
# array([17])

# %%
def find_knee(df):
    slopes = (df['feature'].diff(-1)) / (df['freq'].diff(-1))*(-1)
    knee_index = slopes.idxmax()
    return knee_index

knee_index = find_knee(features_freq)
knee_freq = features_freq.loc[knee_index]['freq']

# import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
plt.plot(features_freq['freq'], features_freq['feature'], 'bo-')  # blue dots with line
plt.xlabel('Frequency')
plt.ylabel('Feature numbers')
plt.title(f"The knee point is at freq = {knee_freq}, optimal feature number: {features_freq.loc[knee_index]['accum']}")
plt.vlines(knee_freq, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
plt.show()

# %%
selected_features = feature_list[feature_list['freq']>=knee_freq]['feature'].tolist()
with open(f'{folder}/SOC-EU/features/002_selected.covar_rank.freq.txt', 'w') as file:
    for item in selected_features:
        file.write(f"{item}\n")

# %%
with open(f'{folder}/SOC-EU/features/002.1_selected.covar.org_rank.freq.txt', 'r') as file:
    lines = file.readlines()
covs_org = [line.strip() for line in lines]

with open(f'{folder}/SOC-EU/features/002.2_selected.covar.mnr_rank.freq.txt', 'r') as file:
    lines = file.readlines()
covs_mnr = [line.strip() for line in lines]

inter = []
for i in covs_org:
    if i in covs_mnr:
        inter.append(i)
        
with open(f'{folder}/SOC-EU/features/002.4_selected.covar,balanced_mnr.org.intersection.txt', 'w') as file:
    for item in inter:
        file.write(f"{item}\n")

# %%
len(inter)
# Out:
# 69

# %%
with open(f'{folder}/SOC-EU/features/002.3_selected.covar_mnr.org.intersection.txt', 'r') as file:
    lines = file.readlines()
inter0 = [line.strip() for line in lines]

# %%
with open(f'{folder}/SOC-EU/features/002.1_selected.covar.org_rank.freq.txt', 'r') as file:
    lines = file.readlines()
covs_org = [line.strip() for line in lines]

with open(f'{folder}/SOC-EU/features/002.2_selected.covar.mnr_rank.freq.txt', 'r') as file:
    lines = file.readlines()
covs_mnr = [line.strip() for line in lines]

inter = []
for i in covs_mnr:
    if i in covs_org:
        inter.append(i)

# %%
with open(f'{folder}/SOC-EU/features/002.3_selected.covar_mnr.org.intersection.txt', 'w') as file:
    for item in inter:
        file.write(f"{item}\n")

# %%
rf = RandomForestRegressor(random_state=41, n_jobs=80, n_estimators=100)
rf.fit(dff[selected_features], dff[tgt])

sorted_importances = sorted(zip(selected_features, rf.feature_importances_), key=lambda x: x[1], reverse=True)
sorted_feature_importance = {feature: importance for feature, importance in sorted_importances}
sorted_feature_importance
# Out:
# {'hzn_btm': 0.1843071211188569,
#  'bioclim.var_chelsa.bio10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.1046726154400965,
#  'ndti_glad.landast.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.09230090648513929,
#  'ai_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.02139342839153947,
#  'ndvi_glad.landsat.ard2.seasconv.longterm_p25_30m_s_20000101_20221231_eu_epsg.3035_v20231127': 0.020843989448785752,
#  'vpd.max_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.018950807307747945,
#  'ndti_glad.landast.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.017536292084345536,
#  'pft.grass.nat_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_eu_epsg.3035_v20230616': 0.014608449850234163,
#  'ndvi_glad.landsat.ard2.seasconv.longterm_p50_30m_s_20000101_20221231_eu_epsg.3035_v20231127': 0.013731485918926705,
#  'accum.ndti_glad.landsat.seasconv.m.yearly_min_30m_s_{year}0101_{year}_eu_epsg.3035_v20240513': 0.012723179867382766,
#  'hzn_dep': 0.012486846583243245,
#  'nir_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211': 0.011453005999186189,
#  'dtm.bareearth_ensemble_p10_60m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.010616789780648282,
#  'nosink.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.010208231184648529,
#  'dtm.bareearth_ensemble_p10_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.009636662328345907,
#  'red_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.009452622375774928,
#  'pft.grass.man_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_eu_epsg.3035_v20230616': 0.009400974435485559,
#  'red_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.009370218426134584,
#  'accum.ndvi_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20240513': 0.009278252854508761,
#  'accum.ndwi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513': 0.009251593949636726,
#  'twi.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.009120614868924716,
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0301_{year}0331_eu_epsg.3035_v20240531': 0.009036065957581902,
#  'ndwi.gao_glad.landsat.ard2.seasconv.longterm_p75_30m_s_20000101_20221231_eu_epsg.3035_v20231218': 0.008763341001748385,
#  'vpd.mean_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.008708451049445448,
#  'twi.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.00868156880051144,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127': 0.008644535749396174,
#  'lst_mod11a2.nighttime_p95_1km_s_{year}1101_{year}1130_eu_epsg.3035_v20240531': 0.008561291166451672,
#  'twi.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.008470391027192796,
#  'rsds.min_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.008408860261488097,
#  'wilderness_li2022.human.footprint_p_1km_s_{year}0101_{year}1231_eu_epsg.3035_v20240531': 0.008406421018267942,
#  'max.curv.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.008294732965895309,
#  'sfcWind.min_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.008066163694687784,
#  'bioclim.var_chelsa.bio3_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.008042477647063433,
#  'twi.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.008015772067687506,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0701_{year}0731_eu_epsg.3035_v20230619.1': 0.00791467356131334,
#  'max.curv.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.007876228501783445,
#  'accum.precipitation_chelsa.annual_m_1km_s_{year}0101_{year}1231_eu_epsg.3035_v20240531': 0.007836273869858287,
#  'rsds.mean_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.007785251273338776,
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0501_{year}0531_eu_epsg.3035_v20240531': 0.00775788467244144,
#  'max.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.007610079896244851,
#  'hzn_top': 0.007562378786503931,
#  'slope.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.007550433000734159,
#  'rsds.range_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.007505683125051359,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127': 0.007499562844816602,
#  'slope.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.007492940510651345,
#  'min.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.007475554885612743,
#  'cmi.mean_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.007393500930682103,
#  'cmi.max_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.0072983162515918186,
#  'spec.catch.area.factor.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.007159110101726104,
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0801_{year}0831_eu_epsg.3035_v20240531': 0.0071393322665669005,
#  'clt.range_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.007047568016914097,
#  'hurs.range_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.006993055251343001,
#  'green_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.006948922435151478,
#  'ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127': 0.006906613076994008,
#  'bioclim.var_chelsa.bio12_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.006763979190821493,
#  'flow.accum.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.006587311203416834,
#  'wv_mcd19a2v061.seasconv_m_1km_s_{year}0901_{year}0930_eu_epsg.3035_v20230619.1': 0.0064700031017849826,
#  'ndti.min_glad.landsat.ard2.seasconv.bimonthly.min_m_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218': 0.006429369080897659,
#  'dtm.bareearth_ensemble_p10_120m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.006199129357191251,
#  'cmi.range_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.0061961454164083385,
#  'pet.penman.min_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.006176338292640438,
#  'lst_mod11a2.daytime_p95_1km_s_{year}0901_{year}0930_eu_epsg.3035_v20240531': 0.006147498962933108,
#  'lst_mod11a2.daytime_p50_1km_s_{year}0901_{year}0930_eu_epsg.3035_v20240531': 0.006089901010207642,
#  'pet.penman.max_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.005999219937289052,
#  'hurs.min_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.005994424943980531,
#  'accum.ndvi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513': 0.00547878750061884,
#  'lst_mod11a2.daytime_p95_1km_s_{year}1001_{year}1031_eu_epsg.3035_v20240531': 0.005448175589329029,
#  'bioclim.var_chelsa.bio9_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822': 0.005418858701715562,
#  'vpd.range_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.005259673023864656,
#  'swir2_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.0051427017560560905,
#  'pet.penman.mean_chelsa_m_1km_s_19810101_20101231_eu_epsg.3035_v20240531': 0.004805449678657117,
#  'green_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127': 0.004631122809860822,
#  'dtm.bareearth_ensemble_p10_960m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.0045469820963012116,
#  'wv_mcd19a2v061.seasconv.m.yearly_p75_1km_s_{year}0101_{year}1231_eu_epsg.3035_v20230619': 0.004215436083780554,
#  'dtm.bareearth_ensemble_p10_480m_s_20000101_20221231_eu_epsg.3035_v20240424': 0.004168871375346263,
#  'pft.trees.ne_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_eu_epsg.3035_v20230616': 0.004074451585337784,
#  'nosink.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501': 0.00393787968239744,
#  'wv_mcd19a2v061.seasconv.m.yearly_p75_1km_s_{year}0101_{year}1231_eu_epsg.3035_v20230619.1': 0.0036207652528331934}
