# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from eumap.misc import find_files, ttprint
from eumap.raster import read_rasters, save_rasters
from eumap.mapper import SpaceOverlay
import warnings
import matplotlib

folder = '/mnt/primus/xuemeng_tmp_harbour/soc'

df = pd.read_csv(f'{folder}/data/001_covar_overlayed.csv',low_memory=False)
# df = pd.read_csv(f'{folder}/data/002_data_whole.csv',low_memory=False)

# %%
for i in df.columns:
    if 'egdi' in i:
        print(i)
# Out:
# dtm_surface.lithology_egdi.1m_c_250m_s_20000101_20221231_eu_epsg.3035_v20240530

# %% [markdown]
# ### convert categorical variables to numerical using dummy

# %%
lithology = '''1	alkaliOlivineBasalt
2	amphibolite
3	andesite
4	anorthositicRock
5	arenite
6	ashBrecciaBombOrBlockTephra
7	ashTuffLapillistoneAndLapilliTuff
8	basalt
9	basanite
10	biogenicSilicaSedimentaryRock
11	breccia
12	brecciaGougeSeries
13	carbonateMud
14	carbonateOoze
15	carbonateSedimentaryRock
16	carbonatite
17	chalk
18	chloriteActinoliteEpidoteMetamorphicRock
19	clasticSandstone
20	clasticSediment
21	clasticSedimentaryMaterial
22	clasticSedimentaryRock
23	clay
24	claystone
25	conglomerate
26	dacite
27	diamictite
28	diamicton
29	diorite
30	dioriticRock
31	doleriticRock
32	dolomite
33	dolomiticOrMagnesianSedimentaryRock
34	eclogite
35	exoticCompositionIgneousRock
36	fineGrainedIgneousRock
37	foidBearingSyenite
38	foidSyenitoid
39	foliatedMetamorphicRock
40	fragmentalIgneousMaterial
41	gabbro
42	gabbroicRock
43	gabbroid
44	glaucophaneLawsoniteEpidoteMetamorphicRock
45	gneiss
46	granite
47	granitoid
48	granodiorite
49	granulite
50	gravel
51	gypsumOrAnhydrite
52	hornfels
53	igneousMaterial
54	igneousRock
55	impactGeneratedMaterial
56	impureCarbonateSediment
57	impureCarbonateSedimentaryRock
58	impureDolomite
59	impureLimestone
60	komatiiticRock
61	limestone
62	marble
63	metamorphicRock
64	metasomaticRock
65	micaSchist
66	migmatite
67	monzogranite
68	monzonite
69	mud
70	mudstone
71	myloniticRock
72	nonClasticSiliceousSedimentaryRock
73	organicBearingMudstone
74	organicRichSediment
75	organicRichSedimentaryMaterial
76	orthogneiss
77	paragneiss
78	peat
79	peridotite
80	phaneriticIgneousRock
81	phonolite
82	phyllite
83	phyllonite
84	porphyry
85	pyroclasticMaterial
86	pyroclasticRock
87	pyroxenite
88	quartzDiorite
89	quartzite
90	residualMaterial
91	rhyolite
92	rhyolitoid
93	rock
94	sand
95	sandstone
96	schist
97	sediment
98	sedimentaryMaterial
99	sedimentaryRock
100	serpentinite
101	shale
102	silicateMud
103	silt
104	siltstone
105	skarn
106	slate
107	spilite
108	syenite
109	syeniticRock
110	syenogranite
111	tephrite
112	tholeiiticBasalt
113	tonalite
114	trachyte
115	trachyticRock
116	trachytoid
117	travertine
118	tuffBrecciaAgglomerateOrPyroclasticBreccia
119	ultramaficIgneousRock
120	wacke
121	waste
122	Unknown
123	Unpopulated'''

lithology = lithology.split('\n')
value = [float(i.split('\t')[0]) for i in lithology]
descp = [i.split('\t')[1] for i in lithology]
descp = ['lithology_EGDI_'+i for i in descp]
lithology_map = dict(zip(value,descp))

# some soil parental material = 0, might from the landmask, mixing water and land
spm = 'dtm_surface.lithology_egdi.1m_c_250m_s_20000101_20221231_eu_epsg.3035_v20240530'
df.loc[df[spm]==0,spm] = np.nan
dummies = pd.get_dummies(df[spm])
dummies = dummies.rename(columns=lithology_map)
dff = pd.concat([df, dummies], axis=1)
dff = dff.drop(columns=[spm])

# add depth thickness
# hzn_dep = hzn_btm+(hzn_top-hzn_btm)/2
dff['hzn_dep'] = dff['hzn_top'] + (dff['hzn_btm']-dff['hzn_top'])/2

# %%
for i in dff.columns:
    if 'hzn' in i:
        print(i)
# Out:
# hzn_top
# hzn_btm
# hzn_dep

# %%
dff = dff.drop(columns=['hzn_top','hzn_btm'])

# %%
dff.to_csv(f'{folder}/data/002_data_whole.csv',index=False)

# %%
len(dff['nuts0'].unique())
# Out:
# 37

# %% [markdown]
# ### get only the sharable ones

# %%
share = pd.read_csv(f'{folder}/data_share/share_or_not.csv')
merged_df = pd.merge(df, share, on='ref', how='left')
share_df = merged_df.loc[merged_df['Can be shared within the consortium']=='Y']

# %%
share_df.to_csv(f'{folder}/data_share/AI4SH_WP5_soil.property.with.cov.csv',index=False)

# %%
prop = pd.read_csv('/mnt/inca/ai4sh_data.harmo/data/AI4SH_WP5_soil.property.csv')
len(prop)
# Out:
# /tmp/ipykernel_343673/3526804972.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   prop = pd.read_csv('/mnt/inca/ai4sh_data.harmo/data/AI4SH_WP5_soil.property.csv')
# 345645

# %%
len(dff)
# Out:
#                                        id        lat       lon    time  \
# 0                                     1-1  40.871480 -7.049093  2000.0
# 1                                     1-2  40.871480 -7.049093  2000.0
# 2                                     2-3  40.583860 -6.952317  2000.0
# 3                                     2-4  40.583860 -6.952317  2000.0
# 4                                     3-5  40.756090 -6.862586  2000.0
# ...                                   ...        ...       ...     ...
# 394638  Diputación de Palencia - DP220201  41.935616 -4.513888  2022.0
# 394639  Diputación de Palencia - DP220202  41.935616 -4.513888  2022.0
# 394640  Diputación de Palencia - DP220030  41.775509 -3.959406  2022.0
# 394641  Diputación de Palencia - DP220090  42.323577 -4.312706  2022.0
# 394642  Diputación de Palencia - DP220163  41.989429 -4.338172  2022.0
#
#         hzn_top  hzn_btm                ref nuts0    oc  ph_h2o  ...  \
# 0           0.0     30.0  portugal.infosolo    PT  6.70     5.2  ...
# 1          30.0     55.0  portugal.infosolo    PT  3.90     5.5  ...
# 2           0.0     13.0  portugal.infosolo    PT  5.90     4.9  ...
# 3          13.0     38.0  portugal.infosolo    PT  6.20     5.2  ...
# 4           0.0     25.0  portugal.infosolo    PT  5.40     5.4  ...
# ...         ...      ...                ...   ...   ...     ...  ...
# 394638      0.0     25.0    Castilla.y.Leon    ES  6.55     NaN  ...
# 394639      0.0     25.0    Castilla.y.Leon    ES  7.35     NaN  ...
# 394640      0.0     25.0    Castilla.y.Leon    ES  4.30     NaN  ...
# 394641      0.0     25.0    Castilla.y.Leon    ES  3.60     NaN  ...
# 394642      0.0     25.0    Castilla.y.Leon    ES  8.90     NaN  ...
#
#         lithology_EGDI_spilite  lithology_EGDI_syenite  \
# 0                        False                   False
# 1                        False                   False
# 2                        False                   False
# 3                        False                   False
# 4                        False                   False
# ...                        ...                     ...
# 394638                   False                   False
# 394639                   False                   False
# 394640                   False                   False
# 394641                   False                   False
# 394642                   False                   False
#
#         lithology_EGDI_tephrite  lithology_EGDI_tonalite  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ...                         ...                      ...
# 394638                    False                    False
# 394639                    False                    False
# 394640                    False                    False
# 394641                    False                    False
# 394642                    False                    False
#
#         lithology_EGDI_trachyte  lithology_EGDI_trachytoid  \
# 0                         False                      False
# 1                         False                      False
# 2                         False                      False
# 3                         False                      False
# 4                         False                      False
# ...                         ...                        ...
# 394638                    False                      False
# 394639                    False                      False
# 394640                    False                      False
# 394641                    False                      False
# 394642                    False                      False
#
#         lithology_EGDI_tuffBrecciaAgglomerateOrPyroclasticBreccia  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 394638                                              False
# 394639                                              False
# 394640                                              False
# 394641                                              False
# 394642                                              False
#
#         lithology_EGDI_ultramaficIgneousRock  lithology_EGDI_wacke  \
# 0                                      False                 False
# 1                                      False                 False
# 2                                      False                 False
# 3                                      False                 False
# 4                                      False                 False
# ...                                      ...                   ...
# 394638                                 False                 False
# 394639                                 False                 False
# 394640                                 False                 False
# 394641                                 False                 False
# 394642                                 False                 False
#
#         lithology_EGDI_Unpopulated
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 394638                       False
# 394639                       False
# 394640                       False
# 394641                       False
# 394642                       False
#
# [394643 rows x 516 columns]

# %%
for i in dff.columns:
    print(i)
# Out:
# id
# lat
# lon
# time
# hzn_top
# hzn_btm
# ref
# nuts0
# oc
# ph_h2o
# ph_cacl2
# bulk_density
# clay
# silt
# sand
# caco3
# N
# K
# P
# CEC
# EC
# oc_qa
# N_qa
# caco3_qa
# bulk_density_qa
# clay_qa
# silt_qa
# sand_qa
# ph_h2o_qa
# ph_cacl2_qa
# P_qa
# K_qa
# EC_qa
# CEC_qa
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0701_{year}0731_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0201_{year}0228_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}1101_{year}1130_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}1101_{year}1130_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0401_{year}0430_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0601_{year}0630_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}1201_{year}1231_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0101_{year}0131_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0401_{year}0430_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0801_{year}0831_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}1001_{year}1031_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}1201_{year}1231_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0201_{year}0228_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0701_{year}0731_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0501_{year}0531_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0801_{year}0831_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0601_{year}0630_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0501_{year}0531_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0901_{year}0930_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}1001_{year}1031_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0901_{year}0930_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_sd_1km_s_{year}0301_{year}0331_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0101_{year}0131_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv_m_1km_s_{year}0301_{year}0331_go_epsg.4326_v20230619
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.06.01..{year}.06.30_v2.1
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.08.01..{year}.08.31_v2.1
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.04.01..{year}.04.30_v2.1
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.07.01..{year}.07.31_v2.1
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.02.01..{year}.02.28_v2.1
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.05.01..{year}.05.31_v2.1
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.09.01..{year}.09.30_v2.1
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.10.01..{year}.10.31_v2.1
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.12.01..{year}.12.31_v2.1
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.03.01..{year}.03.31_v2.1
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.01.01..{year}.01.31_v2.1
# clm_accum.precipitation_chelsa.montlhy_m_1km_s0..0cm_{year}.11.01..{year}.11.30_v2.1
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# pft.shrubs.be_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.snowice_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.shrubs.ne_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.trees.be_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.shrubs.nd_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# pft.water.inland_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.trees.nd_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# pft.water_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# pft.bare_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# pft.built_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# pft.shrubs.bd_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_accum.precipitation_chelsa.annual.3years.dif_m_1km_s0..0cm_{year}_v2.1
# pft.trees.ne_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# pft.grass.man_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.nighttime_p05_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.nighttime_p50_1km_s0..0cm_{year}_v1.2
# pft.trees.bd_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.01.01..{year}.01.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.nighttime_p95_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.02.01..{year}.02.28_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.06.01..{year}.06.30_v1.2
# clm_lst_mod11a2.daytime_p95_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.03.01..{year}.03.31_v1.2
# clm_lst_mod11a2.daytime_p50_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.04.01..{year}.04.30_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.05.01..{year}.05.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.08.01..{year}.08.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.09.01..{year}.09.30_v1.2
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.11.01..{year}.11.30_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.10.01..{year}.10.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# clm_lst_mod11a2.daytime_p05_1km_s0..0cm_{year}.07.01..{year}.07.31_v1.2
# clm_lst_mod11a2.daytime_sd_1km_s0..0cm_{year}_v1.2
# pft.grass.nat_esa.cci.lc_pc_300m_s_{year}0101_{year}1231_go_epsg.4326_v20230616
# clm_accum.precipitation_chelsa.annual_m_1km_s0..0cm_{year}_v2.1
# clm_lst_mod11a2.nighttime_sd_1km_s0..0cm_{year}.12.01..{year}.12.31_v1.2
# wv_mcd19a2v061.seasconv.m.yearly_sd_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv.m.yearly_p50_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv.m.yearly_p25_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619
# wv_mcd19a2v061.seasconv.m.yearly_p75_1km_s_{year}0101_{year}1231_go_epsg.4326_v20230619
# thermal_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# thermal_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# thermal_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# thermal_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# thermal_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# thermal_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# blue_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# blue_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# blue_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# blue_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# blue_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# blue_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# blue_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# green_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# green_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# blue_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# green_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# green_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# green_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# green_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# green_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# green_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# green_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# red_glad.landsat.seasonv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# red_glad.landsat.seasonv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# red_glad.landsat.seasonv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# red_glad.landsat.seasonv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# red_glad.landsat.seasonv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# thermal_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# thermal_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# thermal_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127
# nos_glad.landsat.ard2.seasconv_m_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# swir2_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# dtm.bareearth_ensemble_p10_480m_s_20000101_20221231_eu_epsg.3035_v20240424
# dtm.bareearth_ensemble_p10_960m_s_20000101_20221231_eu_epsg.3035_v20240424
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231218
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231218
# swir2_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231218
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127
# geomorphon.bareearth_ensemble_m_960m_s_20000101_20221231eu_epsg.3035_v20240501
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231218
# geomorphon.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir2_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# hillshade.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240424
# swir2_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127
# bsf_glad.landsat.ard2.seasconv.m.yearly_sum_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# geomorphon.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir2_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127
# ls.factor.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# cdr_glad.landsat.seasconv_m_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# red_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# dtm.bareearth_ensemble_p10_240m_s_20000101_20221231_eu_epsg.3035_v20240424
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127
# max.curv.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231218
# hillshade.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240424
# geomorphon.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir1_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# min.curv.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127
# nir_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# nir_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# neg.openess.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# evi_glad.landsat.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127
# swir1_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231211
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231218
# ls.factor.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# neg.openess.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# nir_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127
# pos.openess.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# nir_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231127
# neg.openess.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir1_glad.landsat.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231211
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231218
# hillshade.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240424
# pos.openess.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0901_{year}1031_eu_epsg.3035_v20231127
# swir1_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# red_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127
# max.curv.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231218
# nir_glad.landsat.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231218
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231218
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127
# swir1_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# geomorphon.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# blue_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# ndwi.gao_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231218
# pos.openess.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127
# min.curv.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndvi_glad.landast.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127
# slope.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.bio10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio11_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio2_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# swir1_glad.landsat.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231211
# bioclim.var_chelsa.bio1_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio15_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# ls.factor.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# twi.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.bio5_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio7_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio6_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio3_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# red_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# bioclim.var_chelsa.bio8_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio9_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gddlgd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# neg.openess.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.gdgfgd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio13_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio17_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gsl_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.ngd0_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio18_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gst_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio14_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.scd_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# max.curv.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.ngd5_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# neg.openess.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.ngd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# pos.openess.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.bio16_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.bio19_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# spec.catch.area.factor.bareearth_ensemble_m_960m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.bio4_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# slope.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# min.curv.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.bio12_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# pos.openess.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# hillshade.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240424
# twi.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# bioclim.var_chelsa.gdd0_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gdd5_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gdd10_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.gsp_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# bioclim.var_chelsa.npp_m_1km_s_19810101_20101231_eu_epsg.3035_v20230822
# slope.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# dtm.bareearth_ensemble_p10_120m_s_20000101_20221231_eu_epsg.3035_v20240424
# hillshade.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# ls.factor.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# twi.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# hillshade.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240424
# swir1_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# spec.catch.area.factor.bareearth_ensemble_m_480m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir1_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231127
# red_glad.landsat.seasonv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231211
# max.curv.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir2_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# min.curv.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir2_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# nosink.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# slope.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir2_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# dtm.bareearth_ensemble_p10_60m_s_20000101_20221231_eu_epsg.3035_v20240424
# twi.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# spec.catch.area.factor.bareearth_ensemble_m_240m_s_20000101_20221231_eu_epsg.3035_v20240501
# max.curv.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndti_glad.landast.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# min.curv.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndsi_glad.landast.ard2.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20231127
# ndti_glad.landast.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# slope.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndti_glad.landast.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# nir_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# nir_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# swir2_glad.landsat.seasconv_m_30m_s_{year}0101_{year}0228_eu_epsg.3035_v20231211
# ls.factor.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndti_glad.landast.ard2.seasconv_m_30m_s_{year}1101_{year}1231_eu_epsg.3035_v20231127
# ndvi_glad.landast.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# savi_glad.landsat.ard2.seasconv.bimonthly.m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231218
# spec.catch.area.factor.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndti.min_glad.landsat.ard2.seasconv.bimonthly.min_m_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218
# nir_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# ndvi_glad.landast.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# nir_glad.landsat.seasconv_m_30m_s_{year}0501_{year}0630_eu_epsg.3035_v20231211
# ndvi_glad.landast.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# ndwi.gao_glad.landsat.ard2.seasconv.m.yearly_p25_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218
# ndwi.gao_glad.landsat.ard2.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218
# flow.accum.bareearth_ensemble_m_120m_s_20000101_20221231_eu_epsg.3035_v20240501
# ndwi.gao_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231218
# fapar_glad.landsat.ard2.seasconv_m_30m_s_{year}0301_{year}0430_eu_epsg.3035_v20231127
# dtm.bareearth_ensemble_p10_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# nosink.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# swir1_glad.landsat.ard2.seasconv.m.yearly_p75_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20231127
# twi.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# max.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501
# slope.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240501
# accum.ndti_glad.landsat.seasconv.m.yearly_min_30m_s_{year}0101_{year}_eu_epsg.3035_v20240513
# accum.ndvi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513
# accum.ndwi_glad.landsat.seasconv.m.yearly_p50_30m_s_{year}0101_{year}1231_eu_epsg.3035_v20240513
# accum.ndvi_glad.landsat.seasconv_m_30m_s_{year}0701_{year}0831_eu_epsg.3035_v20240513
# flow.accum.bareearth_ensemble_m_60m_s_20000101_20221231_eu_epsg.3035_v20240501
# geomorphon.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# neg.openess.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# pos.openess.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# easterness.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# northness.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# min.curv.bareearth_ensemble_m_30m_s_20000101_20221231_eu_epsg.3035_v20240424
# tile_id
# lithology_EGDI_alkaliOlivineBasalt
# lithology_EGDI_amphibolite
# lithology_EGDI_andesite
# lithology_EGDI_anorthositicRock
# lithology_EGDI_arenite
# lithology_EGDI_ashTuffLapillistoneAndLapilliTuff
# lithology_EGDI_basalt
# lithology_EGDI_basanite
# lithology_EGDI_biogenicSilicaSedimentaryRock
# lithology_EGDI_carbonateOoze
# lithology_EGDI_carbonateSedimentaryRock
# lithology_EGDI_chalk
# lithology_EGDI_chloriteActinoliteEpidoteMetamorphicRock
# lithology_EGDI_clasticSediment
# lithology_EGDI_clasticSedimentaryMaterial
# lithology_EGDI_clasticSedimentaryRock
# lithology_EGDI_clay
# lithology_EGDI_claystone
# lithology_EGDI_conglomerate
# lithology_EGDI_dacite
# lithology_EGDI_diamictite
# lithology_EGDI_diamicton
# lithology_EGDI_diorite
# lithology_EGDI_doleriticRock
# lithology_EGDI_dolomite
# lithology_EGDI_eclogite
# lithology_EGDI_fineGrainedIgneousRock
# lithology_EGDI_foliatedMetamorphicRock
# lithology_EGDI_fragmentalIgneousMaterial
# lithology_EGDI_gabbro
# lithology_EGDI_gabbroid
# lithology_EGDI_glaucophaneLawsoniteEpidoteMetamorphicRock
# lithology_EGDI_gneiss
# lithology_EGDI_granite
# lithology_EGDI_granitoid
# lithology_EGDI_granodiorite
# lithology_EGDI_granulite
# lithology_EGDI_gravel
# lithology_EGDI_gypsumOrAnhydrite
# lithology_EGDI_igneousMaterial
# lithology_EGDI_igneousRock
# lithology_EGDI_impactGeneratedMaterial
# lithology_EGDI_impureCarbonateSediment
# lithology_EGDI_impureCarbonateSedimentaryRock
# lithology_EGDI_impureDolomite
# lithology_EGDI_impureLimestone
# lithology_EGDI_komatiiticRock
# lithology_EGDI_limestone
# lithology_EGDI_marble
# lithology_EGDI_metamorphicRock
# lithology_EGDI_metasomaticRock
# lithology_EGDI_micaSchist
# lithology_EGDI_migmatite
# lithology_EGDI_monzogranite
# lithology_EGDI_monzonite
# lithology_EGDI_mud
# lithology_EGDI_mudstone
# lithology_EGDI_myloniticRock
# lithology_EGDI_nonClasticSiliceousSedimentaryRock
# lithology_EGDI_organicBearingMudstone
# lithology_EGDI_organicRichSediment
# lithology_EGDI_organicRichSedimentaryMaterial
# lithology_EGDI_orthogneiss
# lithology_EGDI_paragneiss
# lithology_EGDI_peat
# lithology_EGDI_peridotite
# lithology_EGDI_phyllite
# lithology_EGDI_phyllonite
# lithology_EGDI_porphyry
# lithology_EGDI_pyroclasticMaterial
# lithology_EGDI_pyroclasticRock
# lithology_EGDI_pyroxenite
# lithology_EGDI_quartzDiorite
# lithology_EGDI_quartzite
# lithology_EGDI_residualMaterial
# lithology_EGDI_rhyolite
# lithology_EGDI_rhyolitoid
# lithology_EGDI_sand
# lithology_EGDI_sandstone
# lithology_EGDI_schist
# lithology_EGDI_sediment
# lithology_EGDI_sedimentaryMaterial
# lithology_EGDI_sedimentaryRock
# lithology_EGDI_serpentinite
# lithology_EGDI_shale
# lithology_EGDI_silt
# lithology_EGDI_siltstone
# lithology_EGDI_slate
# lithology_EGDI_spilite
# lithology_EGDI_syenite
# lithology_EGDI_tephrite
# lithology_EGDI_tonalite
# lithology_EGDI_trachyte
# lithology_EGDI_trachytoid
# lithology_EGDI_tuffBrecciaAgglomerateOrPyroclasticBreccia
# lithology_EGDI_ultramaficIgneousRock
# lithology_EGDI_wacke
# lithology_EGDI_Unpopulated

# %%
# ### generate training and validation data

# df = dff
# # get the id of full validation points
# bd_val = pd.read_csv(f'{folder}/data/003.0_validate.pnts.rob_bd.csv',low_memory=False)
# oc_val = pd.read_csv(f'{folder}/data/003.1_validate.pnts.rob_soc.csv',low_memory=False)

# idl = bd_val['id'].values.tolist() + oc_val['id'].values.tolist()
# idl = [str(i) for i in idl]

# test = df.loc[df['id'].isin(idl)]
# train = df.loc[~df['id'].isin(idl)]
# # val.to_csv(f'{folder}/data/004.0_validate.pnts_soc.csv',index=False)

# # # repeat for the properties appear less
# # idl = bd_val['id'].values.tolist()
# # idl = [str(i) for i in idl]

# # val = df.loc[df['id'].isin(idl)]
# # val.to_csv(f'{folder}/data/004.1_validate.pnts_prop.less.freq.csv',index=False)

# # # repeat to get training data, so without
# # idl = bd_val['id'].values.tolist() + oc_val['id'].values.tolist()
# # idl = [str(i) for i in idl]


# # # val.to_csv(f'{folder}/data/005.0_train.pnts_soc.csv',index=False)


# prop_cols = ['oc', 'ph_h2o', 'ph_cacl2', 'bulk_density', 'clay', 'silt', 'sand', 'caco3', 'N', 'K', 'P','CEC','EC']
# qa_filter = [5]

# # # covariates
# # meta_info = ['id','lat','lon','time','ref','nuts0','geometry','tile_id']
# # meta_prop = ['oc','ph_h2o','ph_cacl2','bulk_density','clay','silt','sand','caco3','N','K','P','CEC','EC']
# # meta_qa = [i+'_qa' for i in meta_prop]
# # meta = meta_info + meta_prop + meta_qa + [tgt]
# # covs = [i for i in dff.columns if i not in meta]

# iii = 0

# for prop in prop_cols:
#     istr = str(int(iii))
#     filt = qa_filter[iii]
    
#     train = train.loc[train[prop].notna()]
#     train = train.loc[train[f'{prop}_qa']>filt]
#     train.loc[:,f'{prop}_log1p'] = np.log1p(train[prop])
#     # get 10% of training data as calibration for parameter fine tuning and feature selection
#     cal = train.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(n=max(1, int(np.ceil(0.1 * len(x))))))
#     cal.to_csv(f'{folder}/data/006.{istr}_cal.pnts_{prop}.csv',index=False)
#     # the rest as training dataset
#     new_train = train.drop(cal.index)
#     new_train.to_csv(f'{folder}/data/005.{istr}_train.pnts_{prop}.csv',index=False)

    
#     test = test.loc[test[prop].notna()]
#     test = test.loc[test[f'{prop}_qa']>filt]
#     test.loc[:,f'{prop}_log1p'] = np.log1p(test[prop])
#     test.to_csv(f'{folder}/data/004.{istr}_validate.pnts_{prop}.csv',index=False)
    
#     iii = iii+1
#     if iii>=len(qa_filter):
#         break
        
# print(len(high),len(low),len(new_train),len(train))

# high_cal = high.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(n=max(1, int(np.ceil(0.1 * len(x))))))
# high_train = high.drop(high_cal.index)
# print(len(high),len(high_cal),len(high_train),len(high_cal)+len(+high_train))

# high_train.to_csv(f'{folder}/data/005.2_train.pnts_{prop}.org.csv',index=False)
# high_cal.to_csv(f'{folder}/data/006.1_cal.pnts_{prop}.org.csv',index=False)

# low_cal = low.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(n=max(1, int(np.ceil(0.1 * len(x))))))
# low_train = low.drop(low_cal.index)
# print(len(low),len(low_cal),len(low_train),len(low_cal)+len(+low_train))

# low_train.to_csv(f'{folder}/data/005.3_train.pnts_{prop}.mnr.csv',index=False)
# low_cal.to_csv(f'{folder}/data/006.2_cal.pnts_{prop}.mnr.csv',index=False)

# # for SOC, prepare two calibration sets: organic and mineral
# prop = 'oc'

# train = train.loc[train[prop].notna()]
# train = train.loc[train[f'{prop}_qa']>5]
# train.loc[:,f'{prop}_log1p'] = np.log1p(train[prop])
    
# train_high = train.loc[train[f'{prop}_log1p'] > 5]
# train_low = train.loc[train[f'{prop}_log1p'] <= 5.5]

# high = train_high.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(n=max(1, int(np.ceil(0.5 * len(x))))))
# print(len(high))
# low = train_low.groupby('tile_id', group_keys=False).apply(lambda x: x.sample(n=max(1, int(np.ceil(0.5 * len(x))))))
# print(len(low))
# cal = pd.concat([high, low])
# new_train = train.drop(cal.index)
# new_train.to_csv(f'{folder}/data/005.1_train.pnts_{prop}.org.mnr.csv',index=False)
